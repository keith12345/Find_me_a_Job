# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
inertia = [3166.2771416743185,
 3142.667508304786,
 3124.677508760214,
 3111.489564867894,
 3098.5058343670153,
 3087.9539083888712,
 3080.114310043137,
 3070.9171692696,
 3063.981296776008,
 3054.949705721595,
 3050.849049312611,
 3045.1426939015337,
 3034.8885365657193,
 3028.3809685756582,
 3025.1827551717593,
 3021.235193386092,
 3013.2798964458007,
 3017.8413929641674,
 3008.2186236246757,
 2998.6321679324533,
 2998.264148834926,
 2991.3159650277275,
 2989.7495441543097,
 2986.010056609382,
 2980.716585532233]

# %%
plt.figure(figsize=(15,10))

ax = plt.plot()

means = list(range(2,27))
plt.xticks(means, means, fontsize = '25', family = 'Sans',color='#333335')
plt.yticks(fontsize = '16', family = 'Sans',color='#333335')

plt.suptitle('  Average Q4 Volume',fontsize=26,weight='bold', color='#333335')
plt.title('by Hour by Day of Week',fontsize=20, color='#333335')

plt.ylabel('Average Total Volume',fontsize=25, color='#333335')

plt.legend(title='Station Groups',shadow=True)

#plt.setp(ax.get_legend().get_texts(), fontsize='16',family = 'Sans',color='#333335') # for legend text
#plt.setp(ax.get_legend().get_title(), fontsize='20',family = 'Sans',color='#333335') # for legend title


sns.despine();

# plt.savefig('Average_Hourly_Volume.png')

# %%
fig = plt.figure(figsize=(16,12))
ax = fig.add_axes([0,0,1,1])
ax.scatter([11,15,18,21,23],[inertia[9],inertia[13],inertia[16],inertia[19],inertia[21]],color='green',s=1000)
ax.plot(range(2,27,1),inertia,linewidth=10.0)
#ax.scatter([9],inertia[7],color='red',s=3000)

ax.axes.get_yaxis().set_visible(False)

means = list(range(5,27,5))
plt.xticks(means, means, fontsize = '25', family = 'Sans',color='#333335')



sns.despine();

plt.show()

plt.savefig('KMeans_2.png')

# %%
ax
# Out:
# []

# %%
import pandas as pd

# %%
df = pd.read_pickle('../Data/01_sf_recommender_pca')

# %%
df.head()
# Out:
#          company_name                                       job_title  \
# 0  Gap Inc. Corporate              Software Engineer, Price Execution
# 1              WrkShp                                Business Analyst
# 2       Ceres Imaging  Image Processing: GIS / Remote Sensing Analyst
# 3            Deloitte                  Analyst, Strategy and Research
# 4        Turing Video               Computer Vision Software Engineer
#
#                                         listed_items  \
# 0  write build product according business conduct...
# 1  closely product assist investigation deep dive...
# 2  proficiency gi e g arcgis envi processing prod...
# 3  effectively interpret client request use tacti...
# 4  maintain existing implement algorithm necessar...
#
#                                          posting_url         0         1  \
# 0  https://www.indeed.com/rc/clk?jk=77d524a7cf198... -0.018077  0.014864
# 1  https://www.indeed.com/company/WrkShp/jobs/Bus... -0.049036  0.180958
# ...

# %%
df.drop_duplicates('posting_url',inplace=True)

# %%
df.reset_index(inplace=True,drop=True)

# %%
df.to_pickle('../Data/01_sf_recommender_pca_b')
